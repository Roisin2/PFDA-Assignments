# %%
### Author: Roisin Stanley

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data from the provided URL 
url = 'https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download' 
data = pd.read_csv(url)

# %%
# Display the first few rows to inspect the data
print("Data loaded successfully!")
display(data.head())
# Out:
# Data loaded successfully!
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email               Phone Date of birth  \
# 0            pwarner@example.org        857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net     +1-950-759-8687    1931-07-26
# 2            fhoward@example.org       (599)782-0605    2013-11-25
# 3          zjohnston@example.com     +1-939-130-6258    2012-11-17
# 4               elin@example.net  (390)417-1635x3010    1923-04-15
#
#                   Job Title
# 0         Probation officer
# 1                    Dancer
# 2                      Copy
# 3  Counselling psychologist
# 4       Biomedical engineer

# %%
# Extract email domains
data['domain'] = data['Email'].str.split('@').str[1]

# Count occurrences of each domain
domain_counts = data['domain'].value_counts()

# %%
# Plot a pie chart 
plt.figure(figsize=(10, 10))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Email Domain Distribution')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Plot a pie chart with enhancements
plt.figure(figsize=(12, 12))
#Custom colors 
colors = plt.cm.Paired(range(len(domain_counts))) # Exploding the largest slice
explode = [0.1 if i == 0 else 0 for i in range(len(domain_counts))] 
# Creating the pie chart
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode) 
# Adding a title
plt.title('Email Domain Distribution', fontsize=16, weight='bold', color='darkblue') 
#Adding a legend
plt.legend(domain_counts.index, title='Email Domains', loc='center left', bbox_to_anchor=(1, 0.5))
# Ensuring the pie is a circle
plt.axis('equal') # Adding annotation
plt.text(0, 1.2, 'Distribution of Email Domains', ha='center', va='bottom', fontsize=14,)
# Out:
# Text(0, 1.2, 'Distribution of Email Domains')
